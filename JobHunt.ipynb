# %%
pip install -U python-jobspy
# Out:
# Collecting python-jobspy
#   Downloading python_jobspy-1.1.76-py3-none-any.whl.metadata (10 kB)
# Collecting NUMPY==1.26.3 (from python-jobspy)
#   Downloading numpy-1.26.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 723.9 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /opt/anaconda3/lib/python3.12/site-packages (from python-jobspy) (4.12.3)
# Collecting markdownify<0.14.0,>=0.13.1 (from python-jobspy)
#   Downloading markdownify-0.13.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pandas<3.0.0,>=2.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from python-jobspy) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from python-jobspy) (2.8.2)
# Collecting regex<2025.0.0,>=2024.4.28 (from python-jobspy)
#   Downloading regex-2024.11.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /opt/anaconda3/lib/python3.12/site-packages (from python-jobspy) (2.32.2)
# Collecting tls-client<2.0.0,>=1.0.1 (from python-jobspy)
#   Downloading tls_client-1.0.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.2->python-jobspy) (2.5)
# Requirement already satisfied: six<2,>=1.15 in /opt/anaconda3/lib/python3.12/site-packages (from markdownify<0.14.0,>=0.13.1->python-jobspy) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.3.0->python-jobspy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.3.0->python-jobspy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.3.0->python-jobspy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->python-jobspy) (2024.12.14)
# Downloading python_jobspy-1.1.76-py3-none-any.whl (38 kB)
# Downloading numpy-1.26.3-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 1.9 MB/s eta 0:00:0000:0100:01m
# Downloading markdownify-0.13.1-py3-none-any.whl (10 kB)
# Downloading regex-2024.11.6-cp312-cp312-macosx_11_0_arm64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.8/284.8 kB 1.1 MB/s eta 0:00:00ta 0:00:01
# Downloading tls_client-1.0.1-py3-none-any.whl (41.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 MB 1.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: tls-client, regex, NUMPY, markdownify, python-jobspy
#   Attempting uninstall: regex
#     Found existing installation: regex 2023.10.3
#     Uninstalling regex-2023.10.3:
#       Successfully uninstalled regex-2023.10.3
#   Attempting uninstall: NUMPY
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.4.2 which is incompatible.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# tensorflow-macos 2.16.2 requires tensorflow==2.16.2; platform_system == "Darwin" and platform_machine == "arm64", but you have tensorflow 2.18.0 which is incompatible.
# Successfully installed NUMPY-1.26.3 markdownify-0.13.1 python-jobspy-1.1.76 regex-2024.11.6 tls-client-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "glassdoor", "google"],
    search_term="software engineer",
    google_search_term="software engineer jobs near San Francisco, CA since yesterday",
    location="San Francisco, CA",
    results_wanted=20,
    hours_old=72,
    country_indeed='USA',
    
    # linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# 2025-02-08 20:05:41,478 - INFO - JobSpy:Indeed - search page: 1 / 1
# 2025-02-08 20:05:41,479 - INFO - JobSpy:LinkedIn - search page: 1 / 2
# 2025-02-08 20:05:42,067 - ERROR - JobSpy:Glassdoor - Glassdoor response status code 403
# 2025-02-08 20:05:42,069 - ERROR - JobSpy:Glassdoor - Glassdoor: location not parsed
# 2025-02-08 20:05:42,070 - INFO - JobSpy:Glassdoor - finished scraping
# 2025-02-08 20:05:42,114 - INFO - JobSpy:ZipRecruiter - search page: 1 / 1
# 2025-02-08 20:05:42,436 - INFO - JobSpy:Google - search page: 1 / 2
# 2025-02-08 20:05:42,690 - INFO - JobSpy:Indeed - finished scraping
# 2025-02-08 20:05:43,088 - INFO - JobSpy:Google - finished scraping
# 2025-02-08 20:05:45,771 - INFO - JobSpy:ZipRecruiter - finished scraping
# 2025-02-08 20:05:46,684 - INFO - JobSpy:LinkedIn - search page: 2 / 2
# 2025-02-08 20:05:53,540 - INFO - JobSpy:LinkedIn - search page: 3 / 2
# 2025-02-08 20:05:54,310 - INFO - JobSpy:Linkedin - finished scraping
# Found 80 jobs
#                             id    site  \
# 0  go-yVX64ziHrlZP6nZvAAAAAA==  google
# 1  go-i55yQQVJ6s-OqRh_AAAAAA==  google
# 2  go-Y5mPYceCHIQ66udCAAAAAA==  google
# 3  go-BBK2CLqAi8__3IsVAAAAAA==  google
# 4  go-2LiqSzLFP3AnFArTAAAAAA==  google
#
#                                              job_url job_url_direct  \
# 0  https://us.bebee.com/job/895d364d5eba678ae3ba5...            NaN
# 1  https://www.linkedin.com/jobs/view/entry-level...            NaN
# 2  https://www.linkedin.com/jobs/view/dft-enginee...            NaN
# 3  https://www.linkedin.com/jobs/view/full-stack-...            NaN
# 4  https://www.jointaro.com/jobs/ecl-inc/staff-so...            NaN
#
#                                                title         company  \
# 0                              UI Software Developer           Apple
# 1  Entry-Level Software Engineer (Backend) –AI- P...  Hippocratic AI
# 2                                       DFT Engineer   Sintegra Inc.
# 3  Full Stack Applications Engineer (Javascript, ...          Oracle
# 4    Staff Software Engineer- Individual contributor         ECL Inc
#
#                            location date_posted    job_type salary_source  \
# 0  San Francisco, CA, United States  2025-02-04         NaN           NaN
# 1      Palo Alto, CA, United States  2025-01-29  internship           NaN
# 2  San Francisco, CA, United States  2025-01-27         NaN           NaN
# 3     Pleasanton, CA, United States  2025-01-26         NaN   description
# 4  San Francisco, CA, United States  2025-01-24         NaN           NaN
#
#    ... emails                                        description  \
# 0  ...    NaN  As a UI Engineer at Apple, you will have the o...
# 1  ...    NaN  About Us:\n\nHippocratic AI has developed a sa...
# 2  ...    NaN  Roles & Responsibilities\n\nAs a member of our...
# 3  ...    NaN  Job Description\n\nFusion Applications (FA) is...
# 4  ...    NaN  Staff Software Engineer role at ECL Inc, devel...
#
#    company_industry company_url company_logo company_url_direct  \
# 0               NaN         NaN          NaN                NaN
# 1               NaN         NaN          NaN                NaN
# 2               NaN         NaN          NaN                NaN
# 3               NaN         NaN          NaN                NaN
# 4               NaN         NaN          NaN                NaN
#
#   company_addresses company_num_employees company_revenue company_description
# 0               NaN                   NaN             NaN                 NaN
# 1               NaN                   NaN             NaN                 NaN
# 2               NaN                   NaN             NaN                 NaN
# 3               NaN                   NaN             NaN                 NaN
# 4               NaN                   NaN             NaN                 NaN
#
# [5 rows x 28 columns]

# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["indeed", "linkedin", "glassdoor", "google"],
    search_term="software engineer",
    google_search_term="software engineer jobs near Delhi, India since yesterday",
    location="New Delhi, Delhi",
    results_wanted=20,
    hours_old=72,
    country_indeed='India',
    
    # linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# 2025-02-08 20:07:25,463 - INFO - JobSpy:Indeed - search page: 1 / 1
# 2025-02-08 20:07:25,463 - INFO - JobSpy:LinkedIn - search page: 1 / 2
# 2025-02-08 20:07:26,374 - INFO - JobSpy:Google - search page: 1 / 2
# 2025-02-08 20:07:26,744 - INFO - JobSpy:Google - finished scraping
# 2025-02-08 20:07:27,694 - INFO - JobSpy:Glassdoor - search page: 1 / 1
# 2025-02-08 20:07:27,913 - INFO - JobSpy:Indeed - finished scraping
# 2025-02-08 20:07:29,463 - INFO - JobSpy:Glassdoor - finished scraping
# 2025-02-08 20:07:33,241 - INFO - JobSpy:LinkedIn - search page: 2 / 2
# 2025-02-08 20:07:33,882 - INFO - JobSpy:Linkedin - finished scraping
# Found 80 jobs
#                  id       site  \
# 0  gd-1009631428855  glassdoor
# 1  gd-1009630543861  glassdoor
# 2  gd-1009630055699  glassdoor
# 3  gd-1009630360408  glassdoor
# 4  gd-1009284439111  glassdoor
#
#                                              job_url job_url_direct  \
# 0  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 1  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 2  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 3  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
# 4  https://www.glassdoor.co.in/job-listing/j?jl=1...            NaN
#
#                             title                       company location  \
# 0          UI/Front End Developer                 Womennnovator      NaN
# 1  Software Engineer - COBOL, DB2                         Optum    Noida
# 2      Test Engineer (Automation)             MTAP Technologies  Gurgaon
# 3               ReactJS Developer  Propacity PropTech Pvt. Ltd.      NaN
# 4   Software Development Engineer                     Accenture    Noida
#
#   date_posted job_type salary_source  ... emails  \
# 0  2025-02-08      NaN           NaN  ...    NaN
# 1  2025-02-08      NaN   direct_data  ...    NaN
# 2  2025-02-07      NaN   direct_data  ...    NaN
# 3  2025-02-07      NaN   direct_data  ...    NaN
# 4  2025-02-07      NaN           NaN  ...    NaN
#
#                                          description  company_industry  \
# 0  **Designation** UI/Front End Developer  \n\n  ...               NaN
# 1  Optum is a global organization that delivers c...               NaN
# 2  **Job Brief:**\n\n* ⁠Perform Web \& Mobile App...               NaN
# 3  **What We Do:** \n\nPropacity is one of India'...               NaN
# 4  **Project Role :** Software Development Engine...               NaN
#
#                                          company_url  \
# 0  https://www.glassdoor.co.in/Overview/W-EI_IE67...
# 1  https://www.glassdoor.co.in/Overview/W-EI_IE24...
# 2                                                NaN
# 3                                                NaN
# 4  https://www.glassdoor.co.in/Overview/W-EI_IE41...
#
#                                         company_logo company_url_direct  \
# 0  https://media.glassdoor.com/sql/6732731/womenn...                NaN
# 1  https://media.glassdoor.com/sql/2409113/optum-...                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4  https://media.glassdoor.com/sql/4138/accenture...                NaN
#
#   company_addresses company_num_employees company_revenue company_description
# 0               NaN                   NaN             NaN                 NaN
# 1               NaN                   NaN             NaN                 NaN
# 2               NaN                   NaN             NaN                 NaN
# 3               NaN                   NaN             NaN                 NaN
# 4               NaN                   NaN             NaN                 NaN
#
# [5 rows x 28 columns]
